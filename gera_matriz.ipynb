# %%
# Importando biblioteca que gera numeros aleatorios
import random

dimen = 10 # Dimensão da matriz

# Definindo matriz
matriz = [[random.random() for i in range(10) for j in range(10)]] # gera número aleatório i e j igual a 10
print(matriz) # imprime matriz
# Out:
# [[0.12912828826466405, 0.9133939899960716, 0.7704477245845984, 0.08117136255327018, 0.8943517986610897, 0.43954907243882735, 0.5411747052137401, 0.008445204191591671, 0.11733713958089098, 0.23694076190122781, 0.6536197531202851, 0.041898956221471995, 0.26571677858955434, 0.5276337910301189, 0.1932457482876171, 0.2622717429296051, 0.10631333656082453, 0.47654405704543734, 0.8860054238844862, 0.6292805498186486, 0.30949962919146423, 0.7806257066912862, 0.33687717548567686, 0.8004570339454344, 0.9181270748004217, 0.23226853050485996, 0.09065546924034307, 0.037814249826764956, 0.8429935381883052, 0.5181869716977499, 0.24885516594716361, 0.27774236754529225, 0.5048091446295777, 0.8204816600450531, 0.9526261795034824, 0.8444051281141299, 0.3580266623453121, 0.03989824624326199, 0.2124461134741028, 0.0711846955267591, 0.538813064874488, 0.7602923359610875, 0.5646921690107648, 0.030586888229513165, 0.39847255848660046, 0.17808472276673237, 0.5279651659343012, 0.6598983186899401, 0.1992274262
# ...
